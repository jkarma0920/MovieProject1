# %%
import mysql.connector
import json
import requests
import time
import csv
import config
api_key = config.api_key
config.host
cnx = mysql.connector.connect(
                              host = config.host,
                              user = config.user,
                              passwd = config.passwd,
                              database = "Movie Project1"
                              )
cursor = cnx.cursor()
print(cnx)
# Out:
# <mysql.connector.connection.MySQLConnection object at 0x10ff91fd0>

# %%
with open('Romcom_Movies.csv', 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    movie_titles = []
    for movie in reader:
        movie_titles.append(movie['title'])

# %%
movie_titles
# Out:
# ['What Men Want',
#  'Second Act',
#  'Crazy Rich Asians',
#  'Overboard (2018)',
#  'Home Again',
#  "Bridget Jones's Baby",
#  'How to Be Single',
#  'Trainwreck',
#  'Blended',
#  'About Last Night (2014)',
#  'That Awkward Moment',
#  'Don Jon',
#  'The Big Wedding',
#  'Silver Linings Playbook',
#  "What to Expect When You're Expecting",
#  'The Five-Year Engagement',
#  'Think Like a Man',
#  "New Year's Eve",
#  'Crazy, Stupid, Love.',
#  'Friends with Benefits',
#  'Larry Crowne',
#  'Monte Carlo',
#  'Midnight in Paris',
#  'Something Borrowed',
#  'Jumping the Broom',
#  'Arthur (2011)',
#  'Just Go With It',
#  'No Strings Attached',
#  'How Do You Know',
#  'Life as We Know It',
#  'Easy A',
#  'Going the Distance',
#  'Sex and the City 2',
#  'Letters to Juliet',
#  'The Back-Up Plan',
#  "She's Out of My League",
#  'The Good Guy',
#  "Valentine's Day",
#  'Leap Year',
#  "It's Complicated",
#  'Did You Hear About the Morgans?',
#  'The Ugly Truth',
#  '(500) Days of Summer',
#  'The Proposal',
#  "My Best Friend's Girl",
#  'Everybody Wants to Be Italian',
#  'Sex and the City',
#  'What Happens in Vegas',
#  'Made of Honor',
#  'Forgetting Sarah Marshall',
#  "Fool's Gold",
#  '27 Dresses',
#  'Knocked Up',
#  'Norbit',
#  'The Holiday',
#  'A Good Year',
#  'The Last Kiss (2006)',
#  'The Break-Up',
#  'Failure to Launch',
#  'Prime',
#  'Just Like Heaven',
#  'Side Effects',
#  'Must Love Dogs',
#  'Bewitched',
#  'The Perfect Man',
#  'A Lot Like Love',
#  'Fever Pitch',
#  'Bigger Than the Sky',
#  'Hitch',
#  'The Wedding Date',
#  'Bridget Jones: The Edge of Reason',
#  'Wimbledon',
#  'Little Black Book',
#  "Breakin' All the Rules",
#  'Laws of Attraction',
#  'The Prince and Me',
#  '50 First Dates',
#  'Win a Date with Tad Hamilton!',
#  'Along Came Polly',
#  'Chasing Liberty',
#  "Something's Gotta Give",
#  'Love Actually',
#  'Anything Else',
#  'Alex and Emma',
#  'Boat Trip',
#  'Bringing Down the House',
#  'A Guy Thing',
#  'Just Married',
#  'Two Weeks Notice',
#  'Maid in Manhattan',
#  'Brown Sugar',
#  'Swept Away',
#  'Sweet Home Alabama',
#  'Serving Sara',
#  'Mr. Deeds',
#  'About a Boy',
#  'Life, or Something Like It',
#  'My Big Fat Greek Wedding',
#  'The Sweetest Thing',
#  'Crush',
#  'Kissing Jessica Stein',
#  'Shallow Hal',
#  'On the Line',
#  'Two Can Play That Game',
#  'Summer Catch',
#  "America's Sweethearts",
#  'Town & Country',
#  "Bridget Jones's Diary",
#  'Someone Like You',
#  "Say It Isn't So",
#  'Get Over It',
#  'Down to Earth',
#  'Head Over Heels',
#  'The Wedding Planner',
#  'What Women Want',
#  'Dr. T and the Women',
#  'Woman on Top',
#  'Loser',
#  'Boys and Girls',
#  'Keeping the Faith',
#  'Return to Me',
#  'High Fidelity',
#  'Whatever It Takes',
#  'Down to You',
#  'The Bachelor',
#  'Three to Tango',
#  'Drive Me Crazy',
#  'Mickey Blue Eyes',
#  'Runaway Bride',
#  'Notting Hill',
#  'The Love Letter',
#  "A Midsummer Night's Dream",
#  'Never Been Kissed',
#  '10 Things I Hate About You',
#  'Forces of Nature',
#  'Just the Ticket',
#  'Blast from the Past',
#  'Simply Irresistible',
#  "She's All That",
#  "You've Got Mail",
#  'Shakespeare in Love',
#  'Home Fries',
#  "There's Something About Mary",
#  'Sliding Doors',
#  'The Wedding Singer',
#  'As Good as It Gets',
#  "My Best Friend's Wedding",
#  'The Beautician and the Beast',
#  'Sabrina',
#  'The Perez Family',
#  'While You Were Sleeping',
#  'Don Juan de Marco',
#  'I.Q.',
#  'Four Weddings and a Funeral',
#  'For Love or Money',
#  'Sleepless in Seattle',
#  'Much Ado About Nothing',
#  'Boomerang',
#  'Mannequin Two: On the Move',
#  'The Marrying Man',
#  'Pretty Woman',
#  'Valley Girl']

# %%
len(movie_titles)
# Out:
# 162

# %%
def all_results(api_key, movies):
    results = []
    for i in range(len(movies)):
        title = movies[i]
        url_params = {'term': title.replace(' ', '+')}
        url = f'http://www.omdbapi.com/?apikey={api_key}&t={title}'
        response = requests.get(url, params = url_params)
        results.append(response.json())
        time.sleep(1) # wait a second
    return results

# %%
test = all_results(api_key, movie_titles)

# %%
test
# Out:
# [{'Title': 'What Men Want',
#   'Year': '2019',
#   'Rated': 'R',
#   'Released': '08 Feb 2019',
#   'Runtime': '117 min',
#   'Genre': 'Comedy, Fantasy, Romance',
#   'Director': 'Adam Shankman',
#   'Writer': 'Tina Gordon (screenplay by), Peter Huyck (screenplay by), Alex Gregory (screenplay by), Jas Waters (story by), Tina Gordon (story by), Josh Goldsmith (based on "What Women Want" screenplay by), Cathy Yuspa (based on "What Women Want" screenplay by), Josh Goldsmith (based on "What Women Want" story by), Cathy Yuspa (based on "What Women Want" story by), Diane Drake (based on "What Women Want" story by)',
#   'Actors': 'Taraji P. Henson, Kristen Ledlow, Josh Brener, Kellan Lutz',
#   'Plot': "A woman is boxed out by the male sports agents in her profession, but gains an unexpected edge over them when she develops the ability to hear men's thoughts.",
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYxNjE2NjIwOF5BMl5BanBnXkFtZTgwMjE0MzkxNzM@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.9/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '44%'},
#    {'Source': 'Metacritic', 'Value': '49/100'}],
#   'Metascore': '49',
#   'imdbRating': '4.9',
#   'imdbVotes': '10,927',
#   'imdbID': 'tt7634968',
#   'Type': 'movie',
#   'DVD': '07 May 2019',
#   'BoxOffice': 'N/A',
#   'Production': 'Paramount Pictures',
#   'Website': 'http://www.WhatMenWantMovie.com',
#   'Response': 'True'},
#  {'Title': 'Second Act',
#   'Year': '2018',
#   'Rated': 'PG-13',
#   'Released': '21 Dec 2018',
#   'Runtime': '103 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Peter Segal',
#   'Writer': 'Justin Zackham, Elaine Goldsmith-Thomas',
#   'Actors': 'Jennifer Lopez, Vanessa Hudgens, Leah Remini, Treat Williams',
#   'Plot': 'A big box store worker reinvents her life and her life-story and shows Madison Avenue what street smarts can do.',
#   'Language': 'English, Mandarin',
#   'Country': 'USA',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjQ2MjI5Njk0MF5BMl5BanBnXkFtZTgwNDQ2NzczNTM@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '45%'},
#    {'Source': 'Metacritic', 'Value': '46/100'}],
#   'Metascore': '46',
#   'imdbRating': '5.8',
#   'imdbVotes': '14,446',
#   'imdbID': 'tt2126357',
#   'Type': 'movie',
#   'DVD': '12 Mar 2019',
#   'BoxOffice': 'N/A',
#   'Production': 'STXfilms',
#   'Website': 'https://www.secondact.movie/',
#   'Response': 'True'},
#  {'Title': 'Crazy Rich Asians',
#   'Year': '2018',
#   'Rated': 'PG-13',
#   'Released': '15 Aug 2018',
#   'Runtime': '120 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Jon M. Chu',
#   'Writer': 'Peter Chiarelli (screenplay by), Adele Lim (screenplay by), Kevin Kwan (based on the novel "Crazy Rich Asians" by)',
#   'Actors': 'Constance Wu, Henry Golding, Michelle Yeoh, Gemma Chan',
#   'Plot': "This contemporary romantic comedy, based on a global bestseller, follows native New Yorker Rachel Chu to Singapore to meet her boyfriend's family.",
#   'Language': 'English, Mandarin, Cantonese, Hokkien, French, Malay',
#   'Country': 'USA',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYxNDMyOTAxN15BMl5BanBnXkFtZTgwMDg1ODYzNTM@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '91%'},
#    {'Source': 'Metacritic', 'Value': '74/100'}],
#   'Metascore': '74',
#   'imdbRating': '7.0',
#   'imdbVotes': '102,422',
#   'imdbID': 'tt3104988',
#   'Type': 'movie',
#   'DVD': '20 Nov 2018',
#   'BoxOffice': 'N/A',
#   'Production': 'Warner Bros. Pictures',
#   'Website': 'http://www.crazyrichasiansmovie.com/',
#   'Response': 'True'},
#  {'Response': 'False', 'Error': 'Movie not found!'},
#  {'Title': 'Home Again',
#   'Year': '2017',
#   'Rated': 'PG-13',
#   'Released': '08 Sep 2017',
#   'Runtime': '97 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Hallie Meyers-Shyer',
#   'Writer': 'Hallie Meyers-Shyer',
#   'Actors': 'Reese Witherspoon, Michael Sheen, Candice Bergen, Pico Alexander',
#   'Plot': 'Life for a single mom in Los Angeles takes an unexpected turn when she allows three young guys to move in with her.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNDMxNTQ0NjIwOV5BMl5BanBnXkFtZTgwODE5NjA5MjI@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '33%'},
#    {'Source': 'Metacritic', 'Value': '41/100'}],
#   'Metascore': '41',
#   'imdbRating': '5.8',
#   'imdbVotes': '23,085',
#   'imdbID': 'tt5719700',
#   'Type': 'movie',
#   'DVD': '12 Dec 2017',
#   'BoxOffice': '$26,353,346',
#   'Production': 'Open Road Films',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': "Bridget Jones's Baby",
#   'Year': '2016',
#   'Rated': 'R',
#   'Released': '16 Sep 2016',
#   'Runtime': '123 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Sharon Maguire',
#   'Writer': 'Helen Fielding (screenplay), Dan Mazer (screenplay), Emma Thompson (screenplay), Helen Fielding (based on the characters and story created by)',
#   'Actors': 'Renée Zellweger, Gemma Jones, Jim Broadbent, Sally Phillips',
#   'Plot': "Bridget's focus on single life and her career is interrupted when she finds herself pregnant, but with one hitch ... she can only be fifty percent sure of the identity of her baby's father.",
#   'Language': 'English, Italian',
#   'Country': 'USA, France, China, UK',
#   'Awards': '2 wins & 3 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjQyMTI0MjIyOV5BMl5BanBnXkFtZTgwMzEyMjQ1ODE@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '78%'},
#    {'Source': 'Metacritic', 'Value': '59/100'}],
#   'Metascore': '59',
#   'imdbRating': '6.5',
#   'imdbVotes': '60,364',
#   'imdbID': 'tt1473832',
#   'Type': 'movie',
#   'DVD': '13 Dec 2016',
#   'BoxOffice': '$24,089,465',
#   'Production': 'Working Title',
#   'Website': 'http://www.bridgetjonesmovie.com/',
#   'Response': 'True'},
#  {'Title': 'How to Be Single',
#   'Year': '2016',
#   'Rated': 'R',
#   'Released': '12 Feb 2016',
#   'Runtime': '110 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Christian Ditter',
#   'Writer': 'Abby Kohn (screenplay), Marc Silverstein (screenplay), Dana Fox (screenplay), Abby Kohn (screen story), Marc Silverstein (screen story), Liz Tuccillo (book)',
#   'Actors': 'Dakota Johnson, Rebel Wilson, Leslie Mann, Damon Wayans Jr.',
#   'Plot': 'A group of young adults navigate love and relationships in New York City.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': '3 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNzI4MDMwMzUwNF5BMl5BanBnXkFtZTgwMDgyNzkyNzE@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '46%'},
#    {'Source': 'Metacritic', 'Value': '51/100'}],
#   'Metascore': '51',
#   'imdbRating': '6.1',
#   'imdbVotes': '74,571',
#   'imdbID': 'tt1292566',
#   'Type': 'movie',
#   'DVD': '24 May 2016',
#   'BoxOffice': 'N/A',
#   'Production': 'Warner Bros. Pictures',
#   'Website': 'http://howtobesinglemovie.com/',
#   'Response': 'True'},
#  {'Title': 'Trainwreck',
#   'Year': '2015',
#   'Rated': 'R',
#   'Released': '17 Jul 2015',
#   'Runtime': '125 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Judd Apatow',
#   'Writer': 'Amy Schumer',
#   'Actors': 'Colin Quinn, Devin Fabry, Carla Oudin, Amy Schumer',
#   'Plot': 'Having thought that monogamy was never possible, a commitment-phobic career woman may have to face her fears when she meets a good guy.',
#   'Language': 'English, Mandarin',
#   'Country': 'USA, Japan',
#   'Awards': 'Nominated for 2 Golden Globes. Another 5 wins & 25 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ4MjgwNTMyOV5BMl5BanBnXkFtZTgwMTc1MjI0NDE@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '85%'},
#    {'Source': 'Metacritic', 'Value': '75/100'}],
#   'Metascore': '75',
#   'imdbRating': '6.2',
#   'imdbVotes': '122,111',
#   'imdbID': 'tt3152624',
#   'Type': 'movie',
#   'DVD': '10 Nov 2015',
#   'BoxOffice': 'N/A',
#   'Production': 'Universal Pictures',
#   'Website': 'http://www.trainwreckmovie.com/',
#   'Response': 'True'},
#  {'Title': 'Blended',
#   'Year': '2014',
#   'Rated': 'PG-13',
#   'Released': '23 May 2014',
#   'Runtime': '117 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Frank Coraci',
#   'Writer': 'Ivan Menchell, Clare Sera',
#   'Actors': 'Adam Sandler, Drew Barrymore, Kevin Nealon, Terry Crews',
#   'Plot': 'After a bad blind date, a man and woman find themselves stuck together at a resort for families, where their attraction grows as their respective kids benefit from the burgeoning relationship.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': '1 win & 10 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNzc2ODI5NjAyMl5BMl5BanBnXkFtZTgwMzIyOTE4MDE@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '14%'},
#    {'Source': 'Metacritic', 'Value': '31/100'}],
#   'Metascore': '31',
#   'imdbRating': '6.5',
#   'imdbVotes': '107,141',
#   'imdbID': 'tt1086772',
#   'Type': 'movie',
#   'DVD': '26 Aug 2014',
#   'BoxOffice': 'N/A',
#   'Production': 'Warner Bros. Pictures',
#   'Website': 'http://blendedmovie.com/',
#   'Response': 'True'},
#  {'Response': 'False', 'Error': 'Movie not found!'},
#  {'Title': 'That Awkward Moment',
#   'Year': '2014',
#   'Rated': 'R',
#   'Released': '31 Jan 2014',
#   'Runtime': '94 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Tom Gormican',
#   'Writer': 'Tom Gormican',
#   'Actors': 'Zac Efron, Miles Teller, Michael B. Jordan, Imogen Poots',
#   'Plot': 'Three best friends find themselves where we\'ve all been - at that confusing moment in every dating relationship when you have to decide "So...where is this going?"',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': '1 win & 2 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjExODEyMjMwNV5BMl5BanBnXkFtZTgwMTAyODM1MDE@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '22%'},
#    {'Source': 'Metacritic', 'Value': '36/100'}],
#   'Metascore': '36',
#   'imdbRating': '6.2',
#   'imdbVotes': '92,375',
#   'imdbID': 'tt1800246',
#   'Type': 'movie',
#   'DVD': '13 May 2014',
#   'BoxOffice': '$23,264,422',
#   'Production': 'Focus Features',
#   'Website': 'http://justgethorizontal.com/',
#   'Response': 'True'},
#  {'Title': 'Don Jon',
#   'Year': '2013',
#   'Rated': 'R',
#   'Released': '27 Sep 2013',
#   'Runtime': '90 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Joseph Gordon-Levitt',
#   'Writer': 'Joseph Gordon-Levitt',
#   'Actors': 'Joseph Gordon-Levitt, Scarlett Johansson, Julianne Moore, Tony Danza',
#   'Plot': 'A New Jersey guy dedicated to his family, friends, and church, develops unrealistic expectations from watching porn and works to find happiness and intimacy with his potential true love.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': '2 wins & 27 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQxNTc3NDM2MF5BMl5BanBnXkFtZTcwNzQ5NTQ3OQ@@._V1._CR28,28.649993896484375,1271,1991.0000305175781_SX89_AL_.jpg_V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '79%'},
#    {'Source': 'Metacritic', 'Value': '66/100'}],
#   'Metascore': '66',
#   'imdbRating': '6.6',
#   'imdbVotes': '216,690',
#   'imdbID': 'tt2229499',
#   'Type': 'movie',
#   'DVD': '31 Dec 2013',
#   'BoxOffice': 'N/A',
#   'Production': 'Relativity Media',
#   'Website': 'http://www.facebook.com/DonJonMovie?fref=ts',
#   'Response': 'True'},
#  {'Title': 'The Big Wedding',
#   'Year': '2013',
#   'Rated': 'R',
#   'Released': '26 Apr 2013',
#   'Runtime': '89 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Justin Zackham',
#   'Writer': 'Justin Zackham (screenplay), Jean-Stéphane Bron (motion picture "Mon frère se marie"), Karine Sudan (motion picture "Mon frère se marie")',
#   'Actors': 'Robert De Niro, Katherine Heigl, Diane Keaton, Amanda Seyfried',
#   'Plot': 'A long-divorced couple fakes being married as their family unites for a wedding.',
#   'Language': 'English, Spanish, Chinese, Latin',
#   'Country': 'USA',
#   'Awards': '2 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTcwODUwMjg2Ml5BMl5BanBnXkFtZTcwMTc2NzkxOA@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '7%'},
#    {'Source': 'Metacritic', 'Value': '28/100'}],
#   'Metascore': '28',
#   'imdbRating': '5.6',
#   'imdbVotes': '44,308',
#   'imdbID': 'tt1931435',
#   'Type': 'movie',
#   'DVD': '13 Aug 2013',
#   'BoxOffice': '$21,500,000',
#   'Production': 'Lionsgate Films',
#   'Website': 'http://www.facebook.com/TheBigWeddingMovie',
#   'Response': 'True'},
#  {'Title': 'Silver Linings Playbook',
#   'Year': '2012',
#   'Rated': 'R',
#   'Released': '25 Dec 2012',
#   'Runtime': '122 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'David O. Russell',
#   'Writer': 'David O. Russell (screenplay), Matthew Quick (novel)',
#   'Actors': 'Bradley Cooper, Jennifer Lawrence, Robert De Niro, Jacki Weaver',
#   'Plot': 'After a stint in a mental institution, former teacher Pat Solitano moves back in with his parents and tries to reconcile with his ex-wife. Things get more challenging when Pat meets Tiffany, a mysterious girl with problems of her own.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Won 1 Oscar. Another 88 wins & 145 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTM2MTI5NzA3MF5BMl5BanBnXkFtZTcwODExNTc0OA@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '92%'},
#    {'Source': 'Metacritic', 'Value': '81/100'}],
#   'Metascore': '81',
#   'imdbRating': '7.7',
#   'imdbVotes': '623,385',
#   'imdbID': 'tt1045658',
#   'Type': 'movie',
#   'DVD': '30 Apr 2013',
#   'BoxOffice': '$132,088,910',
#   'Production': 'The Weinstein Company',
#   'Website': 'http://silverliningsplaybookmovie.com/',
#   'Response': 'True'},
#  {'Title': "What to Expect When You're Expecting",
#   'Year': '2012',
#   'Rated': 'PG-13',
#   'Released': '18 May 2012',
#   'Runtime': '110 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Kirk Jones',
#   'Writer': 'Shauna Cross (screenplay), Heather Hach (screenplay), Heidi Murkoff (books)',
#   'Actors': 'Cameron Diaz, Jennifer Lopez, Elizabeth Banks, Chace Crawford',
#   'Plot': 'Follows the lives of five interconnected couples as they experience the thrills and surprises of having a baby and realize that no matter what you plan for, life does not always deliver what is expected.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': '12 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BODYzNjI0ODUzNF5BMl5BanBnXkFtZTcwNTI1MjQ2Nw@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '23%'},
#    {'Source': 'Metacritic', 'Value': '41/100'}],
#   'Metascore': '41',
#   'imdbRating': '5.7',
#   'imdbVotes': '65,990',
#   'imdbID': 'tt1586265',
#   'Type': 'movie',
#   'DVD': '11 Sep 2012',
#   'BoxOffice': '$41,102,171',
#   'Production': 'Lionsgate Films',
#   'Website': 'http://whattoexpectthefilm.com/index.html',
#   'Response': 'True'},
#  {'Title': 'The Five-Year Engagement',
#   'Year': '2012',
#   'Rated': 'R',
#   'Released': '27 Apr 2012',
#   'Runtime': '124 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Nicholas Stoller',
#   'Writer': 'Jason Segel, Nicholas Stoller',
#   'Actors': 'Jason Segel, Emily Blunt, Chris Pratt, Alison Brie',
#   'Plot': 'One year after meeting, Tom proposes to his girlfriend, Violet, but unexpected events keep tripping them up as they look to walk down the aisle together.',
#   'Language': 'English, Spanish',
#   'Country': 'USA, Japan',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk3MDE1NTA3M15BMl5BanBnXkFtZTcwNDcwNTMxNw@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '63%'},
#    {'Source': 'Metacritic', 'Value': '62/100'}],
#   'Metascore': '62',
#   'imdbRating': '6.2',
#   'imdbVotes': '88,838',
#   'imdbID': 'tt1195478',
#   'Type': 'movie',
#   'DVD': '04 Sep 2012',
#   'BoxOffice': '$28,644,770',
#   'Production': 'Universal Pictures',
#   'Website': 'http://www.thefiveyearengagementmovie.com/',
#   'Response': 'True'},
#  {'Title': 'Think Like a Man',
#   'Year': '2012',
#   'Rated': 'PG-13',
#   'Released': '20 Apr 2012',
#   'Runtime': '122 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Tim Story',
#   'Writer': 'Keith Merryman (screenplay), David A. Newman (screenplay), Steve Harvey (book)',
#   'Actors': 'Michael Ealy, Jerry Ferrara, Meagan Good, Regina Hall',
#   'Plot': "Four friends conspire to turn the tables on their women when they discover the ladies have been using Steve Harvey's relationship advice against them.",
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': '4 wins & 13 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjExNTc4NDg3OV5BMl5BanBnXkFtZTcwNTMzNDAxNw@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '54%'},
#    {'Source': 'Metacritic', 'Value': '51/100'}],
#   'Metascore': '51',
#   'imdbRating': '6.6',
#   'imdbVotes': '41,109',
#   'imdbID': 'tt1621045',
#   'Type': 'movie',
#   'DVD': '28 Aug 2012',
#   'BoxOffice': '$91,547,205',
#   'Production': 'Sony Screen Gems',
#   'Website': 'http://www.thinklikeaman-movie.com/site/',
#   'Response': 'True'},
#  {'Title': "New Year's Eve",
#   'Year': '2011',
#   'Rated': 'PG-13',
#   'Released': '09 Dec 2011',
#   'Runtime': '113 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Garry Marshall',
#   'Writer': 'Katherine Fugate',
#   'Actors': 'Michelle Pfeiffer, Zac Efron, Charlotte Marshall-Fricker, Fiona Choi',
#   'Plot': "The lives of several couples and singles in New York City intertwine over the course of New Year's Eve.",
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': '2 wins & 8 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI2Mzg2MDQxOV5BMl5BanBnXkFtZTcwNzc3NTY5Ng@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '7%'},
#    {'Source': 'Metacritic', 'Value': '22/100'}],
#   'Metascore': '22',
#   'imdbRating': '5.7',
#   'imdbVotes': '76,723',
#   'imdbID': 'tt1598822',
#   'Type': 'movie',
#   'DVD': '01 May 2012',
#   'BoxOffice': '$54,538,013',
#   'Production': 'Warner Bros.',
#   'Website': 'http://www.newyearseve-movie.com',
#   'Response': 'True'},
#  {'Title': 'Crazy, Stupid, Love.',
#   'Year': '2011',
#   'Rated': 'PG-13',
#   'Released': '29 Jul 2011',
#   'Runtime': '118 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Glenn Ficarra, John Requa',
#   'Writer': 'Dan Fogelman',
#   'Actors': 'Steve Carell, Ryan Gosling, Julianne Moore, Emma Stone',
#   'Plot': "A middle-aged husband's life changes dramatically when his wife asks him for a divorce. He seeks to rediscover his manhood with the help of a newfound friend, Jacob, learning to pick up girls at bars.",
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Nominated for 1 Golden Globe. Another 3 wins & 21 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg2MjkwMTM0NF5BMl5BanBnXkFtZTcwMzc4NDg2NQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '78%'},
#    {'Source': 'Metacritic', 'Value': '68/100'}],
#   'Metascore': '68',
#   'imdbRating': '7.4',
#   'imdbVotes': '437,544',
#   'imdbID': 'tt1570728',
#   'Type': 'movie',
#   'DVD': '01 Nov 2011',
#   'BoxOffice': '$83,300,000',
#   'Production': 'Warner Bros. Pictures',
#   'Website': 'http://www.crazystupidlovemovie.com',
#   'Response': 'True'},
#  {'Title': 'Friends with Benefits',
#   'Year': '2011',
#   'Rated': 'R',
#   'Released': '22 Jul 2011',
#   'Runtime': '109 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Will Gluck',
#   'Writer': 'Keith Merryman (screenplay), David A. Newman (screenplay), Will Gluck (screenplay), Harley Peyton (story), Keith Merryman (story), David A. Newman (story)',
#   'Actors': 'Justin Timberlake, Mila Kunis, Patricia Clarkson, Jenna Elfman',
#   'Plot': 'A young man and woman decide to take their friendship to the next level without becoming a couple, but soon discover that adding sex only leads to complications.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': '1 win & 5 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ2MzQ0NTk4N15BMl5BanBnXkFtZTcwMDc2NDYzNQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '68%'},
#    {'Source': 'Metacritic', 'Value': '63/100'}],
#   'Metascore': '63',
#   'imdbRating': '6.6',
#   'imdbVotes': '318,877',
#   'imdbID': 'tt1632708',
#   'Type': 'movie',
#   'DVD': '02 Dec 2011',
#   'BoxOffice': '$55,802,754',
#   'Production': 'Sony/Screen Gems',
#   'Website': 'http://www.fwb-movie.com/',
#   'Response': 'True'},
#  {'Title': 'Larry Crowne',
#   'Year': '2011',
#   'Rated': 'PG-13',
#   'Released': '01 Jul 2011',
#   'Runtime': '98 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Tom Hanks',
#   'Writer': 'Tom Hanks, Nia Vardalos',
#   'Actors': 'Tom Hanks, Sarah Mahoney, Roxana Ortega, Randall Park',
#   'Plot': 'After losing his job, a middle-aged man reinvents himself by going back to college.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': '3 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BYjQ4MzlmZDUtN2ViMi00ZTAwLWFkMmItNGRlZmM1NjQ1ZmJjXkEyXkFqcGdeQXVyMzI0NDc4ODY@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '36%'},
#    {'Source': 'Metacritic', 'Value': '41/100'}],
#   'Metascore': '41',
#   'imdbRating': '6.1',
#   'imdbVotes': '59,249',
#   'imdbID': 'tt1583420',
#   'Type': 'movie',
#   'DVD': '15 Nov 2011',
#   'BoxOffice': '$35,565,975',
#   'Production': 'Universal Pictures',
#   'Website': 'http://www.larrycrowne.com/',
#   'Response': 'True'},
#  {'Title': 'Monte Carlo',
#   'Year': '2011',
#   'Rated': 'PG',
#   'Released': '01 Jul 2011',
#   'Runtime': '109 min',
#   'Genre': 'Adventure, Comedy, Family, Romance',
#   'Director': 'Thomas Bezucha',
#   'Writer': 'Thomas Bezucha (screenplay), April Blair (screenplay), Maria Maggenti (screenplay), Kelly Bowe (screen story), Jules Bass (novel)',
#   'Actors': 'Selena Gomez, Katie Cassidy, Leighton Meester, Cory Monteith',
#   'Plot': 'Three young women vacationing in Paris find themselves whisked away to Monte Carlo after one of the girls is mistaken for a British heiress.',
#   'Language': 'English',
#   'Country': 'Hungary, USA',
#   'Awards': '5 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE4NjM3NjI1Nl5BMl5BanBnXkFtZTcwNjA5MzY1NQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '39%'},
#    {'Source': 'Metacritic', 'Value': '43/100'}],
#   'Metascore': '43',
#   'imdbRating': '5.8',
#   'imdbVotes': '38,784',
#   'imdbID': 'tt1067774',
#   'Type': 'movie',
#   'DVD': '18 Oct 2011',
#   'BoxOffice': '$22,500,000',
#   'Production': '20th Century Fox',
#   'Website': 'http://www.facebook.com/officialmontecarlomovie',
#   'Response': 'True'},
#  {'Title': 'Midnight in Paris',
#   'Year': '2011',
#   'Rated': 'PG-13',
#   'Released': '10 Jun 2011',
#   'Runtime': '94 min',
#   'Genre': 'Comedy, Fantasy, Romance',
#   'Director': 'Woody Allen',
#   'Writer': 'Woody Allen',
#   'Actors': 'Owen Wilson, Rachel McAdams, Kurt Fuller, Mimi Kennedy',
#   'Plot': "While on a trip to Paris with his fiancée's family, a nostalgic screenwriter finds himself mysteriously going back to the 1920s everyday at midnight.",
#   'Language': 'English, French, Spanish, German',
#   'Country': 'Spain, USA, France',
#   'Awards': 'Won 1 Oscar. Another 24 wins & 101 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTM4NjY1MDQwMl5BMl5BanBnXkFtZTcwNTI3Njg3NA@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '93%'},
#    {'Source': 'Metacritic', 'Value': '81/100'}],
#   'Metascore': '81',
#   'imdbRating': '7.7',
#   'imdbVotes': '358,273',
#   'imdbID': 'tt1605783',
#   'Type': 'movie',
#   'DVD': '20 Dec 2011',
#   'BoxOffice': '$55,400,000',
#   'Production': 'Sony Pictures Classics',
#   'Website': 'http://www.sonyclassics.com/midnightinparis/',
#   'Response': 'True'},
#  {'Title': 'Something Borrowed',
#   'Year': '2011',
#   'Rated': 'PG-13',
#   'Released': '06 May 2011',
#   'Runtime': '112 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Luke Greenfield',
#   'Writer': 'Jennie Snyder Urman (screenplay), Emily Giffin (novel)',
#   'Actors': 'Ginnifer Goodwin, Kate Hudson, Colin Egglesfield, John Krasinski',
#   'Plot': "Friendships are tested and secrets come to the surface when terminally single Rachel falls for Dex, her best friend Darcy's fiancé.",
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': '5 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNzczNzMzODk0Nl5BMl5BanBnXkFtZTcwMjgwMjI0NA@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.9/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '15%'},
#    {'Source': 'Metacritic', 'Value': '36/100'}],
#   'Metascore': '36',
#   'imdbRating': '5.9',
#   'imdbVotes': '54,379',
#   'imdbID': 'tt0491152',
#   'Type': 'movie',
#   'DVD': '16 Aug 2011',
#   'BoxOffice': '$39,000,000',
#   'Production': 'Warner Bros.',
#   'Website': 'http://somethingborrowedmovie.warnerbros.com/',
#   'Response': 'True'},
#  {'Title': 'Jumping the Broom',
#   'Year': '2011',
#   'Rated': 'PG-13',
#   'Released': '06 May 2011',
#   'Runtime': '112 min',
#   'Genre': 'Comedy, Drama',
#   'Director': 'Salim Akil',
#   'Writer': 'Elizabeth Hunter (screenplay), Arlene Gibbs (screenplay), Elizabeth Hunter (story)',
#   'Actors': 'Angela Bassett, Paula Patton, Laz Alonso, Loretta Devine',
#   'Plot': "Two very different families converge on Martha's Vineyard one weekend for a wedding.",
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': '3 wins & 13 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg4NjA3OTQ0OF5BMl5BanBnXkFtZTcwOTQ1NjA2NA@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '57%'},
#    {'Source': 'Metacritic', 'Value': '56/100'}],
#   'Metascore': '56',
#   'imdbRating': '5.7',
#   'imdbVotes': '9,095',
#   'imdbID': 'tt1640484',
#   'Type': 'movie',
#   'DVD': '09 Aug 2011',
#   'BoxOffice': '$37,295,394',
#   'Production': 'Sony Pictures',
#   'Website': 'http://jumpingthebroom-movie.com/',
#   'Response': 'True'},
#  {'Response': 'False', 'Error': 'Movie not found!'},
#  {'Title': 'Just Go with It',
#   'Year': '2011',
#   'Rated': 'PG-13',
#   'Released': '11 Feb 2011',
#   'Runtime': '117 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Dennis Dugan',
#   'Writer': 'Allan Loeb (screenplay), Timothy Dowling (screenplay), I.A.L. Diamond (screenplay "Cactus Flower"), Abe Burrows (stage play), Pierre Barillet (French play), Jean-Pierre Grédy (French play)',
#   'Actors': 'Adam Sandler, Jennifer Aniston, Nicole Kidman, Nick Swardson',
#   'Plot': 'On a weekend trip to Hawaii, a plastic surgeon convinces his loyal assistant to pose as his soon-to-be-divorced wife in order to cover up a careless lie he told to his much-younger girlfriend.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': '5 wins & 11 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTM3MzM3NDE5MV5BMl5BanBnXkFtZTcwNDE5MTUxNA@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '19%'},
#    {'Source': 'Metacritic', 'Value': '33/100'}],
#   'Metascore': '33',
#   'imdbRating': '6.4',
#   'imdbVotes': '203,086',
#   'imdbID': 'tt1564367',
#   'Type': 'movie',
#   'DVD': '07 Jun 2011',
#   'BoxOffice': '$103,028,109',
#   'Production': 'Sony Pictures',
#   'Website': 'http://www.justgowithit-movie.com/',
#   'Response': 'True'},
#  {'Title': 'No Strings Attached',
#   'Year': '2011',
#   'Rated': 'R',
#   'Released': '21 Jan 2011',
#   'Runtime': '108 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Ivan Reitman',
#   'Writer': 'Elizabeth Meriwether (screenplay), Michael Samonek (story), Elizabeth Meriwether (story)',
#   'Actors': 'Natalie Portman, Ashton Kutcher, Kevin Kline, Cary Elwes',
#   'Plot': "A guy and girl try to keep their relationship strictly physical, but it's not long before they learn that they want something more.",
#   'Language': 'English, Ukrainian',
#   'Country': 'USA',
#   'Awards': '2 wins & 6 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg2MDQ1NTEzNl5BMl5BanBnXkFtZTcwOTgxNTMyNA@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '49%'},
#    {'Source': 'Metacritic', 'Value': '50/100'}],
#   'Metascore': '50',
#   'imdbRating': '6.2',
#   'imdbVotes': '198,814',
#   'imdbID': 'tt1411238',
#   'Type': 'movie',
#   'DVD': '10 May 2011',
#   'BoxOffice': '$70,300,000',
#   'Production': 'Paramount Pictures',
#   'Website': 'http://www.NoStringsAttachedMovie.com/',
#   'Response': 'True'},
#  {'Title': 'How Do You Know',
#   'Year': '2010',
#   'Rated': 'PG-13',
#   'Released': '17 Dec 2010',
#   'Runtime': '121 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'James L. Brooks',
#   'Writer': 'James L. Brooks',
#   'Actors': 'Reese Witherspoon, Paul Rudd, Owen Wilson, Jack Nicholson',
#   'Plot': 'After being cut from the U.S.A. softball team and feeling a bit past her prime, Lisa finds herself evaluating her life and in the middle of a love triangle, as a corporate guy in crisis competes with her current, baseball-playing beau.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': '2 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BOTQyMzU4OTk1N15BMl5BanBnXkFtZTcwNTE5MTUxNA@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '32%'},
#    {'Source': 'Metacritic', 'Value': '46/100'}],
#   'Metascore': '46',
#   'imdbRating': '5.4',
#   'imdbVotes': '41,201',
#   'imdbID': 'tt1341188',
#   'Type': 'movie',
#   'DVD': '22 Mar 2011',
#   'BoxOffice': '$30,212,620',
#   'Production': 'Columbia Pictures',
#   'Website': 'http://www.howdoyouknow-movie.com/',
#   'Response': 'True'},
#  {'Title': 'Life as We Know It',
#   'Year': '2010',
#   'Rated': 'PG-13',
#   'Released': '08 Oct 2010',
#   'Runtime': '114 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Greg Berlanti',
#   'Writer': 'Ian Deitchman, Kristin Robinson',
#   'Actors': 'Katherine Heigl, Josh Duhamel, Josh Lucas, Alexis Clagett',
#   'Plot': 'Two single adults become caregivers to an orphaned girl when their mutual best friends die in an accident.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': '2 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc1OTQzNzE0Nl5BMl5BanBnXkFtZTcwNDU4NDk3Mw@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '29%'},
#    {'Source': 'Metacritic', 'Value': '39/100'}],
#   'Metascore': '39',
#   'imdbRating': '6.6',
#   'imdbVotes': '113,409',
#   'imdbID': 'tt1055292',
#   'Type': 'movie',
#   'DVD': '08 Feb 2011',
#   'BoxOffice': '$53,358,964',
#   'Production': 'Warner Bros. Pictures',
#   'Website': 'http://www.lifeasweknowitmovie.com',
#   'Response': 'True'},
#  {'Title': 'Easy A',
#   'Year': '2010',
#   'Rated': 'PG-13',
#   'Released': '17 Sep 2010',
#   'Runtime': '92 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Will Gluck',
#   'Writer': 'Bert V. Royal',
#   'Actors': 'Emma Stone, Penn Badgley, Amanda Bynes, Dan Byrd',
#   'Plot': "A clean-cut high school student relies on the school's rumor mill to advance her social and financial standing.",
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Nominated for 1 Golden Globe. Another 9 wins & 20 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE1MzU1Mjg1OF5BMl5BanBnXkFtZTcwNDc3NDQ2Mw@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '85%'},
#    {'Source': 'Metacritic', 'Value': '72/100'}],
#   'Metascore': '72',
#   'imdbRating': '7.1',
#   'imdbVotes': '331,318',
#   'imdbID': 'tt1282140',
#   'Type': 'movie',
#   'DVD': '21 Dec 2010',
#   'BoxOffice': '$58,401,464',
#   'Production': 'Sony Pictures/Screen Gems',
#   'Website': 'http://www.letsnotandsaywedid.com/',
#   'Response': 'True'},
#  {'Title': 'Going the Distance',
#   'Year': '2010',
#   'Rated': 'R',
#   'Released': '03 Sep 2010',
#   'Runtime': '102 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Nanette Burstein',
#   'Writer': 'Geoff LaTulippe',
#   'Actors': 'Drew Barrymore, Justin Long, Charlie Day, Jason Sudeikis',
#   'Plot': 'A romantic comedy centered on a guy and a gal who try to keep their love alive as they shuttle back and forth between New York and San Francisco to see one another.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjQ1ODUyMjk5N15BMl5BanBnXkFtZTcwMjAxOTE2Mw@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '53%'},
#    {'Source': 'Metacritic', 'Value': '51/100'}],
#   'Metascore': '51',
#   'imdbRating': '6.3',
#   'imdbVotes': '54,461',
#   'imdbID': 'tt1322312',
#   'Type': 'movie',
#   'DVD': '30 Nov 2010',
#   'BoxOffice': '$17,797,316',
#   'Production': 'New Line Cinema',
#   'Website': 'http://www.going-the-distance.com',
#   'Response': 'True'},
#  {'Title': 'Sex and the City 2',
#   'Year': '2010',
#   'Rated': 'R',
#   'Released': '27 May 2010',
#   'Runtime': '146 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Michael Patrick King',
#   'Writer': 'Michael Patrick King, Candace Bushnell (characters from the book by), Darren Star (television series creator)',
#   'Actors': 'Sarah Jessica Parker, Kristin Davis, Cynthia Nixon, Kim Cattrall',
#   'Plot': "While wrestling with the pressures of life, love, and work in Manhattan, Carrie, Miranda, and Charlotte join Samantha for a trip to Abu Dhabi (United Arab Emirates), where Samantha's ex is filming a new movie.",
#   'Language': 'English, Arabic',
#   'Country': 'USA',
#   'Awards': '8 wins & 9 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTM3OTUyNTI3MF5BMl5BanBnXkFtZTcwODcyMzM0Mw@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '16%'},
#    {'Source': 'Metacritic', 'Value': '27/100'}],
#   'Metascore': '27',
#   'imdbRating': '4.4',
#   'imdbVotes': '69,339',
#   'imdbID': 'tt1261945',
#   'Type': 'movie',
#   'DVD': '26 Oct 2010',
#   'BoxOffice': '$95,328,937',
#   'Production': 'Warner Bros. Pictures',
#   'Website': 'http://sexandthecitymovie.com/',
#   'Response': 'True'},
#  {'Title': 'Letters to Juliet',
#   'Year': '2010',
#   'Rated': 'PG',
#   'Released': '14 May 2010',
#   'Runtime': '105 min',
#   'Genre': 'Adventure, Comedy, Drama, Romance',
#   'Director': 'Gary Winick',
#   'Writer': 'Jose Rivera, Tim Sullivan',
#   'Actors': 'Amanda Seyfried, Marcia DeBonis, Gael García Bernal, Giordano Formenti',
#   'Plot': 'Sophie dreams of becoming a writer and travels to Verona, Italy where she meets the "Secretaries of Juliet".',
#   'Language': 'English, Italian, Spanish',
#   'Country': 'USA',
#   'Awards': '6 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjg0OTU0NDYwNF5BMl5BanBnXkFtZTcwNzUwNTMyMw@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '41%'},
#    {'Source': 'Metacritic', 'Value': '50/100'}],
#   'Metascore': '50',
#   'imdbRating': '6.6',
#   'imdbVotes': '86,111',
#   'imdbID': 'tt0892318',
#   'Type': 'movie',
#   'DVD': '14 Sep 2010',
#   'BoxOffice': '$53,021,560',
#   'Production': 'Summit Entertainment',
#   'Website': 'http://LettersToJuliet-Movie.com/',
#   'Response': 'True'},
#  {'Title': 'The Back-up Plan',
#   'Year': '2010',
#   'Rated': 'PG-13',
#   'Released': '23 Apr 2010',
#   'Runtime': '104 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Alan Poul',
#   'Writer': 'Kate Angelo',
#   'Actors': "Jennifer Lopez, Alex O'Loughlin, Michaela Watkins, Eric Christian Olsen",
#   'Plot': 'A woman conceives twins through artificial insemination, only to meet the man of her dreams on the very same day.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': '2 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNjAzODM4NTc1OF5BMl5BanBnXkFtZTcwNDU2ODUzMw@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '18%'},
#    {'Source': 'Metacritic', 'Value': '34/100'}],
#   'Metascore': '34',
#   'imdbRating': '5.4',
#   'imdbVotes': '46,335',
#   'imdbID': 'tt1212436',
#   'Type': 'movie',
#   'DVD': '24 Aug 2010',
#   'BoxOffice': '$37,481,242',
#   'Production': 'CBS Films',
#   'Website': 'http://www.theback-upplan.com/',
#   'Response': 'True'},
#  {'Title': "She's Out of My League",
#   'Year': '2010',
#   'Rated': 'R',
#   'Released': '12 Mar 2010',
#   'Runtime': '104 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Jim Field Smith',
#   'Writer': 'Sean Anders, John Morris',
#   'Actors': 'Jay Baruchel, Alice Eve, T.J. Miller, Mike Vogel',
#   'Plot': 'An average Joe meets the perfect woman, but his lack of confidence and the influence of his friends and family begin to pick away at the relationship.',
#   'Language': 'English, Ukrainian',
#   'Country': 'USA',
#   'Awards': '1 nomination.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTkwMTY5ODA1MF5BMl5BanBnXkFtZTcwODYyNzAxMw@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '58%'},
#    {'Source': 'Metacritic', 'Value': '46/100'}],
#   'Metascore': '46',
#   'imdbRating': '6.4',
#   'imdbVotes': '117,484',
#   'imdbID': 'tt0815236',
#   'Type': 'movie',
#   'DVD': '22 Jun 2010',
#   'BoxOffice': '$28,712,974',
#   'Production': 'Paramount',
#   'Website': 'http://www.hard10movie.com/',
#   'Response': 'True'},
#  {'Title': 'The Good Guy',
#   'Year': '2009',
#   'Rated': 'R',
#   'Released': '19 Feb 2010',
#   'Runtime': '90 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Julio DePietro',
#   'Writer': 'Julio DePietro',
#   'Actors': 'Alexis Bledel, Scott Porter, Bryan Greenberg, Colin Egglesfield',
#   'Plot': "Calm and quiet Daniel starts on Wall Street. His womanizing colleague, Tommy, encourages him to meet women. He unknowingly meets Tommy's girlfriend, Beth, and ends up in her 5 women book club. Will he find the woman?",
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc3MTExMzIzMV5BMl5BanBnXkFtZTcwMjI1MzUxMw@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '35%'},
#    {'Source': 'Metacritic', 'Value': '47/100'}],
#   'Metascore': '47',
#   'imdbRating': '5.8',
#   'imdbVotes': '8,677',
#   'imdbID': 'tt1247662',
#   'Type': 'movie',
#   'DVD': '22 Jun 2010',
#   'BoxOffice': '$34,712',
#   'Production': 'Roadside Attractions',
#   'Website': 'http://www.thegoodguyfilm.com/',
#   'Response': 'True'},
#  {'Title': "Valentine's Day",
#   'Year': '2010',
#   'Rated': 'PG-13',
#   'Released': '12 Feb 2010',
#   'Runtime': '125 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Garry Marshall',
#   'Writer': 'Katherine Fugate (screenplay), Katherine Fugate (story), Abby Kohn (story), Marc Silverstein (story)',
#   'Actors': 'Jessica Alba, Kathy Bates, Jessica Biel, Bradley Cooper',
#   'Plot': "Intertwining couples and singles in Los Angeles break-up and make-up based on the pressures and expectations of Valentine's Day.",
#   'Language': 'English, Spanish, Russian, Italian',
#   'Country': 'USA',
#   'Awards': '7 wins & 12 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk3MTIwNDIxNF5BMl5BanBnXkFtZTcwMDMyMzcwMw@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '18%'},
#    {'Source': 'Metacritic', 'Value': '34/100'}],
#   'Metascore': '34',
#   'imdbRating': '5.7',
#   'imdbVotes': '107,571',
#   'imdbID': 'tt0817230',
#   'Type': 'movie',
#   'DVD': '18 May 2010',
#   'BoxOffice': '$110,500,000',
#   'Production': 'New Line Cinema/Warner Bros. Pictures',
#   'Website': 'http://www.valentinesdaymovie.com/',
#   'Response': 'True'},
#  {'Title': 'Leap Year',
#   'Year': '2010',
#   'Rated': 'PG',
#   'Released': '08 Jan 2010',
#   'Runtime': '100 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Anand Tucker',
#   'Writer': 'Deborah Kaplan, Harry Elfont',
#   'Actors': 'Amy Adams, Matthew Goode, Adam Scott, John Lithgow',
#   'Plot': 'Anna Brady plans to travel to Dublin, Ireland to propose marriage to her boyfriend Jeremy on Leap Day, because, according to Irish tradition, a man who receives a marriage proposal on a leap day must accept it.',
#   'Language': 'English, Ukrainian',
#   'Country': 'USA, Ireland',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTgzMTQ2MDQxMF5BMl5BanBnXkFtZTcwODEzOTg5Mg@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '23%'},
#    {'Source': 'Metacritic', 'Value': '33/100'}],
#   'Metascore': '33',
#   'imdbRating': '6.5',
#   'imdbVotes': '86,373',
#   'imdbID': 'tt1216492',
#   'Type': 'movie',
#   'DVD': '04 May 2010',
#   'BoxOffice': '$25,893,485',
#   'Production': 'Universal Pictures/Spyglass',
#   'Website': 'http://www.universalpictures.com/leapyear/',
#   'Response': 'True'},
#  {'Title': "It's Complicated",
#   'Year': '2009',
#   'Rated': 'R',
#   'Released': '25 Dec 2009',
#   'Runtime': '120 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Nancy Meyers',
#   'Writer': 'Nancy Meyers',
#   'Actors': 'Meryl Streep, Steve Martin, Alec Baldwin, John Krasinski',
#   'Plot': "When attending their son's college graduation, a couple reignite the spark in their relationship. But the complicated fact is they're divorced and he's remarried.",
#   'Language': 'English, French',
#   'Country': 'USA, Japan',
#   'Awards': 'Nominated for 3 Golden Globes. Another 8 wins & 12 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjQ0NjM2NTI4N15BMl5BanBnXkFtZTcwNjQ2MDc5Mg@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '58%'},
#    {'Source': 'Metacritic', 'Value': '57/100'}],
#   'Metascore': '57',
#   'imdbRating': '6.6',
#   'imdbVotes': '80,966',
#   'imdbID': 'tt1230414',
#   'Type': 'movie',
#   'DVD': '27 Apr 2010',
#   'BoxOffice': '$112,703,470',
#   'Production': 'Universal Pictures',
#   'Website': 'http://www.itscomplicatedmovie.com/',
#   'Response': 'True'},
#  {'Title': 'Did You Hear About the Morgans?',
#   'Year': '2009',
#   'Rated': 'PG-13',
#   'Released': '18 Dec 2009',
#   'Runtime': '103 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Marc Lawrence',
#   'Writer': 'Marc Lawrence',
#   'Actors': 'Hugh Grant, Sarah Jessica Parker, Natalia Klimas, Vincenzo Amato',
#   'Plot': 'In New York City, an estranged couple who witness a murder are relocated to small town Wyoming as part of the Witness Protection Program.',
#   'Language': 'English, Ukrainian, French, Italian, Spanish',
#   'Country': 'USA',
#   'Awards': '1 nomination.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjUzMDY0NDYzN15BMl5BanBnXkFtZTcwNjgxMDI5Mg@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '12%'},
#    {'Source': 'Metacritic', 'Value': '27/100'}],
#   'Metascore': '27',
#   'imdbRating': '4.8',
#   'imdbVotes': '35,047',
#   'imdbID': 'tt1314228',
#   'Type': 'movie',
#   'DVD': '16 Mar 2010',
#   'BoxOffice': '$29,580,087',
#   'Production': 'Sony Pictures/Columbia',
#   'Website': 'http://www.didyouhearaboutthemorgans.com/',
#   'Response': 'True'},
#  {'Title': 'The Ugly Truth',
#   'Year': '2009',
#   'Rated': 'R',
#   'Released': '24 Jul 2009',
#   'Runtime': '96 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Robert Luketic',
#   'Writer': 'Nicole Eastman (screenplay), Karen McCullah (screenplay), Kirsten Smith (screenplay), Nicole Eastman (story)',
#   'Actors': 'Katherine Heigl, Gerard Butler, Bree Turner, Eric Winter',
#   'Plot': 'An uptight television producer takes control of a morning show segment on modern relationships hosted by a misogynistic man.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': '3 wins & 5 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTM2MTM2OTUwNl5BMl5BanBnXkFtZTcwNTgwNTE0Mg@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '14%'},
#    {'Source': 'Metacritic', 'Value': '28/100'}],
#   'Metascore': '28',
#   'imdbRating': '6.4',
#   'imdbVotes': '190,833',
#   'imdbID': 'tt1142988',
#   'Type': 'movie',
#   'DVD': '10 Nov 2009',
#   'BoxOffice': '$88,915,214',
#   'Production': 'Sony/Columbia Pictures',
#   'Website': 'http://www.theuglytruth-movie.com/',
#   'Response': 'True'},
#  {'Title': 'Not a Love Story: Making (500) Days of Summer',
#   'Year': '2009',
#   'Rated': 'Not Rated',
#   'Released': '22 Dec 2009',
#   'Runtime': '30 min',
#   'Genre': 'Documentary, Short',
#   'Director': 'Charles de Lauzirika',
#   'Writer': 'N/A',
#   'Actors': 'Zooey Deschanel, Joseph Gordon-Levitt, Scott Neustadter, Marc Webb',
#   'Plot': "A behind-the-scenes documentary exploring the making of Marc Webb's 500 Days of Summer (2009).",
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'N/A',
#   'Poster': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'}],
#   'Metascore': 'N/A',
#   'imdbRating': '7.8',
#   'imdbVotes': '41',
#   'imdbID': 'tt1572162',
#   'Type': 'movie',
#   'DVD': 'N/A',
#   'BoxOffice': 'N/A',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Proposal',
#   'Year': '2009',
#   'Rated': 'PG-13',
#   'Released': '19 Jun 2009',
#   'Runtime': '108 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Anne Fletcher',
#   'Writer': 'Peter Chiarelli',
#   'Actors': 'Sandra Bullock, Ryan Reynolds, Mary Steenburgen, Craig T. Nelson',
#   'Plot': 'A pushy boss forces her young assistant to marry her in order to keep her visa status in the U.S. and avoid deportation to Canada.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Nominated for 1 Golden Globe. Another 7 wins & 19 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BOGM5YTNiYzktNmEwZC00ZjE5LWIyNzEtOTUwNDE0NmVkYzE3XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '44%'},
#    {'Source': 'Metacritic', 'Value': '48/100'}],
#   'Metascore': '48',
#   'imdbRating': '6.7',
#   'imdbVotes': '273,751',
#   'imdbID': 'tt1041829',
#   'Type': 'movie',
#   'DVD': '13 Oct 2009',
#   'BoxOffice': '$163,900,057',
#   'Production': 'Walt Disney Pictures',
#   'Website': 'http://www.myspace.com/proposalmovie',
#   'Response': 'True'},
#  {'Title': "My Best Friend's Girl",
#   'Year': '2008',
#   'Rated': 'R',
#   'Released': '19 Sep 2008',
#   'Runtime': '101 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Howard Deutch',
#   'Writer': 'Jordan Cahan',
#   'Actors': 'Dane Cook, Kate Hudson, Alec Baldwin, Jason Biggs',
#   'Plot': 'Tank faces the ultimate test of friendship when his best friend hires him to take his ex-girlfriend out on a lousy date in order to make her realize how great her former boyfriend is.',
#   'Language': 'English',
#   'Country': 'USA',
# ...
#    {'Source': 'Rotten Tomatoes', 'Value': '85%'},
#    {'Source': 'Metacritic', 'Value': '67/100'}],
#   'Metascore': '67',
#   'imdbRating': '7.7',
#   'imdbVotes': '254,777',
#   'imdbID': 'tt0119822',
#   'Type': 'movie',
#   'DVD': '19 May 1998',
#   'BoxOffice': 'N/A',
#   'Production': 'TriStar Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': "My Best Friend's Wedding",
#   'Year': '1997',
#   'Rated': 'PG-13',
#   'Released': '20 Jun 1997',
#   'Runtime': '105 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'P.J. Hogan',
#   'Writer': 'Ronald Bass',
#   'Actors': 'Julia Roberts, Dermot Mulroney, Cameron Diaz, Rupert Everett',
#   'Plot': "When a woman's long-time friend reveals he's engaged, she realizes she loves him herself and sets out to get him, with only days before the wedding.",
#   'Language': 'English, French, Italian',
#   'Country': 'USA',
#   'Awards': 'Nominated for 1 Oscar. Another 12 wins & 22 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMzRiMGE2MmMtM2RhMy00OWNiLTljYTktOThmMmE1YjY1NjYyXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '73%'},
#    {'Source': 'Metacritic', 'Value': '50/100'}],
#   'Metascore': '50',
#   'imdbRating': '6.3',
#   'imdbVotes': '117,718',
#   'imdbID': 'tt0119738',
#   'Type': 'movie',
#   'DVD': '09 Dec 1997',
#   'BoxOffice': 'N/A',
#   'Production': 'Sony Pictures Entertainment',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Beautician and the Beast',
#   'Year': '1997',
#   'Rated': 'PG',
#   'Released': '07 Feb 1997',
#   'Runtime': '105 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Ken Kwapis',
#   'Writer': 'Todd Graff',
#   'Actors': 'Fran Drescher, Timothy Dalton, Ian McNeice, Patrick Malahide',
#   'Plot': 'A New York City cosmetologist, mistakenly thought to be a science teacher, is offered a job to teach the children of an Eastern European dictator.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': '1 nomination.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BOGViZjFhM2MtOGNmZC00MWQyLWJiM2MtODdkMDdlYmFmMjYzXkEyXkFqcGdeQXVyMTkzODUwNzk@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '18%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '5.4',
#   'imdbVotes': '7,884',
#   'imdbID': 'tt0118691',
#   'Type': 'movie',
#   'DVD': '24 Jun 2003',
#   'BoxOffice': 'N/A',
#   'Production': 'Paramount Home Video',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Sabrina',
#   'Year': '1954',
#   'Rated': 'Not Rated',
#   'Released': '15 Oct 1954',
#   'Runtime': '113 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Billy Wilder',
#   'Writer': 'Billy Wilder (written for the screen by), Samuel A. Taylor (written for the screen by), Ernest Lehman (written for the screen by), Samuel A. Taylor (from the play by)',
#   'Actors': 'Humphrey Bogart, Audrey Hepburn, William Holden, Walter Hampden',
#   'Plot': "A playboy becomes interested in the daughter of his family's chauffeur, but it's his more serious brother who would be the better man for her.",
#   'Language': 'English, French',
#   'Country': 'USA',
#   'Awards': 'Won 1 Oscar. Another 5 wins & 8 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BYmFlNTA1NWItODQxNC00YjFmLWE3ZWYtMzg3YTkwYmMxMjY2XkEyXkFqcGdeQXVyMTMxMTY0OTQ@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '92%'},
#    {'Source': 'Metacritic', 'Value': '72/100'}],
#   'Metascore': '72',
#   'imdbRating': '7.7',
#   'imdbVotes': '53,677',
#   'imdbID': 'tt0047437',
#   'Type': 'movie',
#   'DVD': '10 Apr 2001',
#   'BoxOffice': 'N/A',
#   'Production': 'Paramount Home Video',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Perez Family',
#   'Year': '1995',
#   'Rated': 'R',
#   'Released': '12 May 1995',
#   'Runtime': '113 min',
#   'Genre': 'Comedy, Romance, Drama',
#   'Director': 'Mira Nair',
#   'Writer': 'Christine Bell (novel), Robin Swicord (screenplay)',
#   'Actors': 'Marisa Tomei, Alfred Molina, Anjelica Huston, Chazz Palminteri',
#   'Plot': 'In an attempt to secure a sponsor, an unlikely group of Cuban refugees become a "family" as the U.S. Immigration and Naturalization Service gives families priority over others. In the ...',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk1MTI2Nzg0NF5BMl5BanBnXkFtZTcwOTcwOTc2NA@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '65%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '6.1',
#   'imdbVotes': '1,992',
#   'imdbID': 'tt0114113',
#   'Type': 'movie',
#   'DVD': '01 Apr 2003',
#   'BoxOffice': 'N/A',
#   'Production': 'Hallmark Entertainment',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'While You Were Sleeping',
#   'Year': '1995',
#   'Rated': 'PG',
#   'Released': '21 Apr 1995',
#   'Runtime': '103 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Jon Turteltaub',
#   'Writer': 'Daniel G. Sullivan, Fredric Lebow',
#   'Actors': 'Sandra Bullock, Bill Pullman, Peter Gallagher, Peter Boyle',
#   'Plot': 'A hopeless romantic Chicago Transit Authority token collector is mistaken for the fiancée of a coma patient.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Nominated for 1 Golden Globe. Another 4 wins & 4 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU5NjU4NDUzMl5BMl5BanBnXkFtZTgwMjc4NDgzMTE@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '81%'},
#    {'Source': 'Metacritic', 'Value': '67/100'}],
#   'Metascore': '67',
#   'imdbRating': '6.7',
#   'imdbVotes': '84,514',
#   'imdbID': 'tt0114924',
#   'Type': 'movie',
#   'DVD': '03 Feb 1998',
#   'BoxOffice': 'N/A',
#   'Production': 'Buena Vista Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Response': 'False', 'Error': 'Movie not found!'},
#  {'Title': 'I.Q.',
#   'Year': '1994',
#   'Rated': 'PG',
#   'Released': '25 Dec 1994',
#   'Runtime': '100 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Fred Schepisi',
#   'Writer': 'Andy Breckman (story), Andy Breckman (screenplay), Michael Leeson (screenplay)',
#   'Actors': 'Tim Robbins, Meg Ryan, Walter Matthau, Lou Jacobi',
#   'Plot': 'A mechanic romances the mathematician niece of physicist Albert Einstein, with help from Einstein and his friends.',
#   'Language': 'English, German',
#   'Country': 'USA',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BN2VkMzZlMTctZjVlOS00NmQ1LTg1ZDItMDc5NzhlNDRhMjRiXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '44%'},
#    {'Source': 'Metacritic', 'Value': '66/100'}],
#   'Metascore': '66',
#   'imdbRating': '6.2',
#   'imdbVotes': '22,226',
#   'imdbID': 'tt0110099',
#   'Type': 'movie',
#   'DVD': '23 Sep 2003',
#   'BoxOffice': 'N/A',
#   'Production': 'Paramount Home Video',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Four Weddings and a Funeral',
#   'Year': '1994',
#   'Rated': 'R',
#   'Released': '15 Apr 1994',
#   'Runtime': '117 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Mike Newell',
#   'Writer': 'Richard Curtis',
#   'Actors': 'Hugh Grant, James Fleet, Simon Callow, John Hannah',
#   'Plot': 'Over the course of five social occasions, a committed bachelor must consider the notion that he may have discovered love.',
#   'Language': 'English, British Sign Language',
#   'Country': 'UK',
#   'Awards': 'Nominated for 2 Oscars. Another 24 wins & 23 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTMyNzg2NzgxNV5BMl5BanBnXkFtZTcwMTcxNzczNA@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '96%'},
#    {'Source': 'Metacritic', 'Value': '81/100'}],
#   'Metascore': '81',
#   'imdbRating': '7.1',
#   'imdbVotes': '127,116',
#   'imdbID': 'tt0109831',
#   'Type': 'movie',
#   'DVD': '07 Sep 1999',
#   'BoxOffice': 'N/A',
#   'Production': 'Gramercy Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'For Love or Money',
#   'Year': '1993',
#   'Rated': 'PG',
#   'Released': '01 Oct 1993',
#   'Runtime': '96 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Barry Sonnenfeld',
#   'Writer': 'Mark Rosenthal, Lawrence Konner',
#   'Actors': 'Michael J. Fox, Gabrielle Anwar, Anthony Higgins, Michael Tucker',
#   'Plot': "Doug's a concierge at a luxury hotel on Manhattan. He saves all his tips towards his plan for a hotel. A potential investor seduces the girl, Doug loves, with false promises of leaving his wife. Doug's dilemma: hotel project or girl?",
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BYjg1NGE4YjQtNGU3Yi00ZWJiLWFkZGYtY2Y2YTE0Njc3YTdiXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '37%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '6.1',
#   'imdbVotes': '11,050',
#   'imdbID': 'tt0106941',
#   'Type': 'movie',
#   'DVD': '12 Aug 2003',
#   'BoxOffice': 'N/A',
#   'Production': 'MCA Universal Home Video',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Sleepless in Seattle',
#   'Year': '1993',
#   'Rated': 'PG',
#   'Released': '25 Jun 1993',
#   'Runtime': '105 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Nora Ephron',
#   'Writer': 'Jeff Arch (story), Nora Ephron (screenplay), David S. Ward (screenplay), Jeff Arch (screenplay)',
#   'Actors': 'Tom Hanks, Ross Malinger, Rita Wilson, Victor Garber',
#   'Plot': "A recently widowed man's son calls a radio talk-show in an attempt to find his father a partner.",
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Nominated for 2 Oscars. Another 4 wins & 17 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNWY1MDJkZGUtZTE2OS00ODZiLTlmNzQtMDZjNzM2ZjkwM2QxXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '73%'},
#    {'Source': 'Metacritic', 'Value': '72/100'}],
#   'Metascore': '72',
#   'imdbRating': '6.8',
#   'imdbVotes': '145,530',
#   'imdbID': 'tt0108160',
#   'Type': 'movie',
#   'DVD': '26 Jun 1997',
#   'BoxOffice': 'N/A',
#   'Production': 'TriStar Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Much Ado About Nothing',
#   'Year': '1993',
#   'Rated': 'PG-13',
#   'Released': '02 Jul 1993',
#   'Runtime': '111 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Kenneth Branagh',
#   'Writer': 'William Shakespeare (play), Kenneth Branagh (adaptation)',
#   'Actors': 'Richard Briers, Kate Beckinsale, Imelda Staunton, Jimmy Yuill',
#   'Plot': 'Young lovers Hero and Claudio, soon to wed, conspire to get verbal sparring partners and confirmed singles Benedick and Beatrice to wed as well.',
#   'Language': 'English',
#   'Country': 'UK, USA',
#   'Awards': 'Nominated for 1 Golden Globe. Another 5 wins & 10 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BY2Q3YTU4OTgtZTc0My00YmY1LWJmOTQtMmMwNGE2ZjBmNmIxXkEyXkFqcGdeQXVyMTAwMzUyOTc@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '90%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '7.4',
#   'imdbVotes': '42,395',
#   'imdbID': 'tt0107616',
#   'Type': 'movie',
#   'DVD': '01 Jan 1998',
#   'BoxOffice': 'N/A',
#   'Production': 'Screenvision',
#   'Website': 'http://www.GlobeOnScreen.com',
#   'Response': 'True'},
#  {'Title': 'Boomerang',
#   'Year': '1992',
#   'Rated': 'R',
#   'Released': '01 Jul 1992',
#   'Runtime': '117 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Reginald Hudlin',
#   'Writer': 'Barry W. Blaustein (screenplay by), David Sheffield (screenplay by), Eddie Murphy (story by)',
#   'Actors': 'Eddie Murphy, Robin Givens, Halle Berry, David Alan Grier',
#   'Plot': 'A successful executive and womanizer finds his lifestyle choices have turned back on him when his new female boss turns out to be an even bigger deviant than he is.',
#   'Language': 'English, French',
#   'Country': 'USA',
#   'Awards': '1 win & 4 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BZDZmZDU5MGYtMTU3YS00NDczLWJmOTQtOTdlODk2NmMxZjllXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '44%'},
#    {'Source': 'Metacritic', 'Value': '45/100'}],
#   'Metascore': '45',
#   'imdbRating': '5.5',
#   'imdbVotes': '23,711',
#   'imdbID': 'tt0103859',
#   'Type': 'movie',
#   'DVD': '24 Sep 2002',
#   'BoxOffice': 'N/A',
#   'Production': 'Paramount Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Response': 'False', 'Error': 'Movie not found!'},
#  {'Title': 'The Marrying Man',
#   'Year': '1991',
#   'Rated': 'R',
#   'Released': '05 Apr 1991',
#   'Runtime': '115 min',
#   'Genre': 'Comedy, Music, Romance',
#   'Director': 'Jerry Rees',
#   'Writer': 'Neil Simon',
#   'Actors': 'Kim Basinger, Alec Baldwin, Robert Loggia, Elisabeth Shue',
#   'Plot': 'A millionaire playboy goes into Las Vegas and comes out married to a woman he barely knows.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': '1 nomination.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMzQ2MzJkMDAtODM4Mi00NTkxLTgyNjYtYTk0ZTE0MDQ4MGRjXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '10%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '5.7',
#   'imdbVotes': '4,818',
#   'imdbID': 'tt0102411',
#   'Type': 'movie',
#   'DVD': '08 Apr 2003',
#   'BoxOffice': 'N/A',
#   'Production': 'Hollywood Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Pretty Woman',
#   'Year': '1990',
#   'Rated': 'R',
#   'Released': '23 Mar 1990',
#   'Runtime': '119 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Garry Marshall',
#   'Writer': 'J.F. Lawton',
#   'Actors': 'Richard Gere, Julia Roberts, Ralph Bellamy, Jason Alexander',
#   'Plot': 'A man in a legal but hurtful business needs an escort for some social events, and hires a beautiful prostitute he meets... only to fall in love.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Nominated for 1 Oscar. Another 8 wins & 10 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNjk2ODQzNDYxNV5BMl5BanBnXkFtZTgwMTcyNDg4NjE@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '62%'},
#    {'Source': 'Metacritic', 'Value': '51/100'}],
#   'Metascore': '51',
#   'imdbRating': '7.0',
#   'imdbVotes': '262,010',
#   'imdbID': 'tt0100405',
#   'Type': 'movie',
#   'DVD': '19 May 1998',
#   'BoxOffice': 'N/A',
#   'Production': 'Buena Vista',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Valley Girl',
#   'Year': '1983',
#   'Rated': 'R',
#   'Released': '29 Apr 1983',
#   'Runtime': '99 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Martha Coolidge',
#   'Writer': 'Andrew Lane, Wayne Crawford',
#   'Actors': 'Nicolas Cage, Deborah Foreman, Elizabeth Daily, Michael Bowen',
#   'Plot': 'Julie, a girl from the valley, meets Randy, a punk from the city. They are from different worlds and find love. Somehow they need to stay together in spite of her trendy, shallow friends.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA4NzI5OTgyMV5BMl5BanBnXkFtZTgwODgwNjU1MDE@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'},
#    {'Source': 'Metacritic', 'Value': '66/100'}],
#   'Metascore': '66',
#   'imdbRating': '6.4',
#   'imdbVotes': '11,889',
#   'imdbID': 'tt0086525',
#   'Type': 'movie',
#   'DVD': '01 Mar 2005',
#   'BoxOffice': 'N/A',
#   'Production': 'MGM Home Entertainment',
#   'Website': 'N/A',
#   'Response': 'True'}]

# %%
# def all_ratings(movies):
#     all_data = []
#     for movie in movies:
#         if 'Title' in movie.keys():
#             if len(movie['Ratings']) >= 2 and movie['Ratings'][1]['Source'] = 'Rotten Tomatoes':
#                 data = {'Title': movie['Title'],
#                         'Metascore': movie['Metascore'],
#                         'imdbRating': movie['imdbRating'],
#                         'Rotten Tomatoes': movie['Ratings'][1]['Value']}
#                 all_data.append(data)
#     return all_data

# %%
def all_ratings(movies):
    all_data = []
    for movie in movies:
        if 'Title' in movie.keys():
            try:
                data = {'Title': movie['Title'],
                       'imdbRating': float(movie['imdbRating'])}
            except:
                continue
            cursor = cnx.cursor()
            try:
                cursor.execute("""INSERT INTO Reviews (title, ratings)
                                           VALUES (%s, %s)""", (data['Title'], data['imdbRating']))
            except:
                pass
            cnx.commit()
            all_data.append(data)
    return all_data

# %%
final_test = all_ratings(test)

# %%
final_test
# Out:
# [{'Title': 'What Men Want', 'imdbRating': 4.9},
#  {'Title': 'Second Act', 'imdbRating': 5.8},
#  {'Title': 'Crazy Rich Asians', 'imdbRating': 7.0},
#  {'Title': 'Home Again', 'imdbRating': 5.8},
#  {'Title': "Bridget Jones's Baby", 'imdbRating': 6.5},
#  {'Title': 'How to Be Single', 'imdbRating': 6.1},
#  {'Title': 'Trainwreck', 'imdbRating': 6.2},
#  {'Title': 'Blended', 'imdbRating': 6.5},
#  {'Title': 'That Awkward Moment', 'imdbRating': 6.2},
#  {'Title': 'Don Jon', 'imdbRating': 6.6},
#  {'Title': 'The Big Wedding', 'imdbRating': 5.6},
#  {'Title': 'Silver Linings Playbook', 'imdbRating': 7.7},
#  {'Title': "What to Expect When You're Expecting", 'imdbRating': 5.7},
#  {'Title': 'The Five-Year Engagement', 'imdbRating': 6.2},
#  {'Title': 'Think Like a Man', 'imdbRating': 6.6},
#  {'Title': "New Year's Eve", 'imdbRating': 5.7},
#  {'Title': 'Crazy, Stupid, Love.', 'imdbRating': 7.4},
#  {'Title': 'Friends with Benefits', 'imdbRating': 6.6},
#  {'Title': 'Larry Crowne', 'imdbRating': 6.1},
#  {'Title': 'Monte Carlo', 'imdbRating': 5.8},
#  {'Title': 'Midnight in Paris', 'imdbRating': 7.7},
#  {'Title': 'Something Borrowed', 'imdbRating': 5.9},
#  {'Title': 'Jumping the Broom', 'imdbRating': 5.7},
#  {'Title': 'Just Go with It', 'imdbRating': 6.4},
#  {'Title': 'No Strings Attached', 'imdbRating': 6.2},
#  {'Title': 'How Do You Know', 'imdbRating': 5.4},
#  {'Title': 'Life as We Know It', 'imdbRating': 6.6},
#  {'Title': 'Easy A', 'imdbRating': 7.1},
#  {'Title': 'Going the Distance', 'imdbRating': 6.3},
#  {'Title': 'Sex and the City 2', 'imdbRating': 4.4},
#  {'Title': 'Letters to Juliet', 'imdbRating': 6.6},
#  {'Title': 'The Back-up Plan', 'imdbRating': 5.4},
#  {'Title': "She's Out of My League", 'imdbRating': 6.4},
#  {'Title': 'The Good Guy', 'imdbRating': 5.8},
#  {'Title': "Valentine's Day", 'imdbRating': 5.7},
#  {'Title': 'Leap Year', 'imdbRating': 6.5},
#  {'Title': "It's Complicated", 'imdbRating': 6.6},
#  {'Title': 'Did You Hear About the Morgans?', 'imdbRating': 4.8},
#  {'Title': 'The Ugly Truth', 'imdbRating': 6.4},
#  {'Title': 'Not a Love Story: Making (500) Days of Summer', 'imdbRating': 7.8},
#  {'Title': 'The Proposal', 'imdbRating': 6.7},
#  {'Title': "My Best Friend's Girl", 'imdbRating': 5.9},
#  {'Title': 'Everybody Wants to Be Italian', 'imdbRating': 5.9},
#  {'Title': 'Sex and the City', 'imdbRating': 5.6},
#  {'Title': 'What Happens in Vegas', 'imdbRating': 6.1},
#  {'Title': 'Made of Honor', 'imdbRating': 5.9},
#  {'Title': 'Forgetting Sarah Marshall', 'imdbRating': 7.2},
#  {'Title': "Fool's Gold", 'imdbRating': 5.7},
#  {'Title': '27 Dresses', 'imdbRating': 6.1},
#  {'Title': 'Knocked Up', 'imdbRating': 7.0},
#  {'Title': 'Norbit', 'imdbRating': 4.0},
#  {'Title': 'The Holiday', 'imdbRating': 6.9},
#  {'Title': 'A Good Year', 'imdbRating': 7.0},
#  {'Title': 'The Break-Up', 'imdbRating': 5.8},
#  {'Title': 'Failure to Launch', 'imdbRating': 5.6},
#  {'Title': 'Prime', 'imdbRating': 6.2},
#  {'Title': 'Just Like Heaven', 'imdbRating': 6.7},
#  {'Title': 'Side Effects', 'imdbRating': 7.1},
#  {'Title': 'Must Love Dogs', 'imdbRating': 5.9},
#  {'Title': 'Bewitched', 'imdbRating': 4.8},
#  {'Title': 'The Perfect Man', 'imdbRating': 5.5},
#  {'Title': 'A Lot Like Love', 'imdbRating': 6.6},
#  {'Title': 'Fever Pitch', 'imdbRating': 6.2},
#  {'Title': 'Bigger Than the Sky', 'imdbRating': 6.1},
#  {'Title': 'Hitch', 'imdbRating': 6.6},
#  {'Title': 'The Wedding Date', 'imdbRating': 6.1},
#  {'Title': 'Bridget Jones: The Edge of Reason', 'imdbRating': 6.0},
#  {'Title': 'Wimbledon', 'imdbRating': 6.3},
#  {'Title': 'Little Black Book', 'imdbRating': 5.3},
#  {'Title': "Breakin' All the Rules", 'imdbRating': 5.6},
#  {'Title': 'Laws of Attraction', 'imdbRating': 5.9},
#  {'Title': 'The Prince and Me', 'imdbRating': 5.9},
#  {'Title': '50 First Dates', 'imdbRating': 6.8},
#  {'Title': 'Win a Date with Tad Hamilton!', 'imdbRating': 5.6},
#  {'Title': 'Along Came Polly', 'imdbRating': 5.9},
#  {'Title': 'Chasing Liberty', 'imdbRating': 6.1},
#  {'Title': "Something's Gotta Give", 'imdbRating': 6.7},
#  {'Title': 'Love Actually', 'imdbRating': 7.6},
#  {'Title': 'Anything Else', 'imdbRating': 6.4},
#  {'Title': 'Boat Trip', 'imdbRating': 4.9},
#  {'Title': 'Bringing Down the House', 'imdbRating': 5.6},
#  {'Title': 'A Guy Thing', 'imdbRating': 5.6},
#  {'Title': 'Just Married', 'imdbRating': 5.5},
#  {'Title': 'Two Weeks Notice', 'imdbRating': 6.1},
#  {'Title': 'Maid in Manhattan', 'imdbRating': 5.2},
#  {'Title': 'Brown Sugar', 'imdbRating': 6.5},
#  {'Title': 'Swept Away', 'imdbRating': 3.6},
#  {'Title': 'Sweet Home Alabama', 'imdbRating': 6.2},
#  {'Title': 'Serving Sara', 'imdbRating': 5.3},
#  {'Title': 'Mr. Deeds', 'imdbRating': 5.8},
#  {'Title': 'About a Boy', 'imdbRating': 7.1},
#  {'Title': 'Life or Something Like It', 'imdbRating': 5.8},
#  {'Title': 'My Big Fat Greek Wedding', 'imdbRating': 6.6},
#  {'Title': 'The Sweetest Thing', 'imdbRating': 5.1},
#  {'Title': 'Crush', 'imdbRating': 5.7},
#  {'Title': 'Kissing Jessica Stein', 'imdbRating': 6.6},
#  {'Title': 'Shallow Hal', 'imdbRating': 5.9},
#  {'Title': 'On the Line', 'imdbRating': 4.1},
#  {'Title': 'Two Can Play That Game', 'imdbRating': 6.1},
#  {'Title': 'Summer Catch', 'imdbRating': 5.0},
#  {'Title': "America's Sweethearts", 'imdbRating': 5.7},
#  {'Title': 'The Town That Dreaded Sundown', 'imdbRating': 5.6},
#  {'Title': "Bridget Jones's Diary", 'imdbRating': 6.7},
#  {'Title': 'Someone Like You', 'imdbRating': 7.8},
#  {'Title': "Say It Isn't So", 'imdbRating': 5.0},
#  {'Title': 'Get Over It', 'imdbRating': 5.8},
#  {'Title': 'Down to Earth', 'imdbRating': 5.4},
#  {'Title': 'Head Over Heels', 'imdbRating': 5.4},
#  {'Title': 'The Wedding Planner', 'imdbRating': 5.3},
#  {'Title': 'What Women Want', 'imdbRating': 6.4},
#  {'Title': "The Making of 'Dr. T and the Women'", 'imdbRating': 3.6},
#  {'Title': 'Woman on Top', 'imdbRating': 5.3},
#  {'Title': 'Loser', 'imdbRating': 5.3},
#  {'Title': 'Boys and Girls', 'imdbRating': 5.4},
#  {'Title': 'Keeping the Faith', 'imdbRating': 6.4},
#  {'Title': 'Return to Me', 'imdbRating': 6.9},
#  {'Title': 'High Fidelity', 'imdbRating': 7.5},
#  {'Title': 'Whatever It Takes', 'imdbRating': 5.5},
#  {'Title': 'Down to You', 'imdbRating': 5.0},
#  {'Title': 'The Bachelor', 'imdbRating': 5.0},
#  {'Title': 'Three to Tango', 'imdbRating': 6.1},
#  {'Title': 'Drive Me Crazy', 'imdbRating': 5.8},
#  {'Title': 'Mickey Blue Eyes', 'imdbRating': 5.8},
#  {'Title': 'Runaway Bride', 'imdbRating': 5.5},
#  {'Title': 'Notting Hill', 'imdbRating': 7.1},
#  {'Title': 'The Love Letter', 'imdbRating': 5.4},
#  {'Title': "A Midsummer Night's Dream", 'imdbRating': 6.4},
#  {'Title': 'Never Been Kissed', 'imdbRating': 6.1},
#  {'Title': '10 Things I Hate About You', 'imdbRating': 7.3},
#  {'Title': 'Forces of Nature', 'imdbRating': 5.4},
#  {'Title': 'Just the Ticket', 'imdbRating': 5.6},
#  {'Title': 'Blast from the Past', 'imdbRating': 6.6},
#  {'Title': 'Simply Irresistible', 'imdbRating': 5.3},
#  {'Title': "She's All That", 'imdbRating': 5.9},
#  {'Title': "You've Got Mail", 'imdbRating': 6.6},
#  {'Title': 'Shakespeare in Love', 'imdbRating': 7.1},
#  {'Title': 'Home Fries', 'imdbRating': 5.0},
#  {'Title': "There's Something About Mary", 'imdbRating': 7.1},
#  {'Title': 'Sliding Doors', 'imdbRating': 6.7},
#  {'Title': 'The Wedding Singer', 'imdbRating': 6.8},
#  {'Title': 'As Good as It Gets', 'imdbRating': 7.7},
#  {'Title': "My Best Friend's Wedding", 'imdbRating': 6.3},
#  {'Title': 'The Beautician and the Beast', 'imdbRating': 5.4},
#  {'Title': 'Sabrina', 'imdbRating': 7.7},
#  {'Title': 'The Perez Family', 'imdbRating': 6.1},
#  {'Title': 'While You Were Sleeping', 'imdbRating': 6.7},
#  {'Title': 'I.Q.', 'imdbRating': 6.2},
#  {'Title': 'Four Weddings and a Funeral', 'imdbRating': 7.1},
#  {'Title': 'For Love or Money', 'imdbRating': 6.1},
#  {'Title': 'Sleepless in Seattle', 'imdbRating': 6.8},
#  {'Title': 'Much Ado About Nothing', 'imdbRating': 7.4},
#  {'Title': 'Boomerang', 'imdbRating': 5.5},
#  {'Title': 'The Marrying Man', 'imdbRating': 5.7},
#  {'Title': 'Pretty Woman', 'imdbRating': 7.0},
#  {'Title': 'Valley Girl', 'imdbRating': 6.4}]

# %%
len(final_test)
# Out:
# 155

# %%
data_list = final_test

keys = data_list[0].keys()
with open('Romcom_Ratings.csv', 'w') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(data_list)
