# %%
import requests
page = requests.get("https://www.boxofficemojo.com/genres/chart/?id=animation.htm&sort=date&order=DESC&p=.htm")
page
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup as bs
soup = bs(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="en">
#  <head>
#   <title>
#    Animation Movies at the Box Office - Box Office Mojo
#   </title>
#   <meta content="animation, movie, movies, box office, gross, open, opening, report, result" name="keywords"/>
#   <meta content="Top Grossing Animation Movies at the Box Office." name="description"/>
#   <link charset="utf-8" href="/css/mojo.css?1" media="screen" rel="stylesheet" title="no title" type="text/css"/>
#   <link charset="utf-8" href="/css/mojo.css?1" media="print" rel="stylesheet" title="no title" type="text/css"/>
#  </head>
#  <body>
#   <iframe frameborder="0" height="1" id="sis_pixel_sitewide" marginheight="0" marginwidth="0" style="display: none;" width="1">
#   </iframe>
#   <script>
#    setTimeout(function(){
#         try{
#             //sis3.0 pixel
#             var cacheBust = Math.random() * 10000000000000000,
# ...

# %%
addthis = soup.find("div", id="addthis").nextSibling.nextSibling

# %%
a = addthis.find_all("a")
a[61].find("b").get_text()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-160-918646be08b3> in <module>
#       1 a = addthis.find_all("a")
# ----> 2 a[61].find("b").get_text()
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
titles = []
for i in range(len(a)):
    try:
        titles.append(a[i].find("b").get_text())
    except:
        pass

titles = titles[1:]
titles
# Out:
# ['Is It Wrong to Try to Pick Up Girls in a Dungeon?: Arrow of the Orion',
#  'The Lion King (2019)',
#  'Sound! Euphonium the Movie - Our Promise: A Brand New Day',
#  'Toy Story 4',
#  'The Secret Life of Pets 2',
#  'Funan',
#  'Uglydolls',
#  'Ploey',
#  "Okko's Inn",
#  "The Pilgrim's Progress",
#  'Missing Link',
#  'Trinity Seven: Heavens Library & Crimson Lord',
#  "Made In Abyss: Journey's Dawn",
#  'Wonder Park',
#  'This Magnificent Cake!',
#  'How to Train Your Dragon: The Hidden World',
#  'Asterix: The Secret of the Magic Potion',
#  'Ruben Brandt, Collector',
#  'The LEGO Movie 2: The Second Part',
#  'I Want to Eat Your Pancreas',
#  'Peppa Celebrates Chinese New Year',
#  'Tito and the Birds',
#  'Dragon Ball Super: Broly',
#  'Spider-Man: Into The Spider-Verse',
#  'Racetime',
#  'Henchmen',
#  'Mirai',
#  'Pokemon the Movie: The Power of Us',
#  'Ralph Breaks the Internet',
#  'Castle in the Sky - Studio Ghibli Fest 2018',
#  "Dr. Seuss' The Grinch (2018)",
# ...

# %%
import csv

with open('animation_titles.csv', 'w') as csvFile:
    writer = csv.writer(csvFile)
    writer.writerow(titles)
csvFile.close()

# %%
href = []
for i in range(len(bgcolor)):
    href.append(bgcolor[i].find_all("a"))
len(href)
# Out:
# 7
