# %%
import mysql.connector
from mysql.connector import errorcode
import json
import requests
import time
import pandas as pd
import csv
import config
config.host
api_key = config.api_key

# %%
with open('Animation_Movies.csv', 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    movie_titles = []
    for movie in reader:
        movie_titles.append(movie['title'])

# %%
movie_titles
# Out:
# ['Is It Wrong to Try to Pick Up Girls in a Dungeon?: Arrow of the Orion',
#  'The Lion King (2019)',
#  'Sound! Euphonium the Movie - Our Promise: A Brand New Day',
#  'Toy Story 4',
#  'The Secret Life of Pets 2',
#  'Funan',
#  'Uglydolls',
#  'Ploey',
#  "Okko's Inn",
#  "The Pilgrim's Progress",
#  'Missing Link',
#  'Trinity Seven: Heavens Library & Crimson Lord',
#  "Made In Abyss: Journey's Dawn",
#  'Wonder Park',
#  'This Magnificent Cake!',
#  'How to Train Your Dragon: The Hidden World',
#  'Asterix: The Secret of the Magic Potion',
#  'Ruben Brandt, Collector',
#  'The LEGO Movie 2: The Second Part',
#  'I Want to Eat Your Pancreas',
#  'Peppa Celebrates Chinese New Year',
#  'Tito and the Birds',
#  'Dragon Ball Super: Broly',
#  'Spider-Man: Into The Spider-Verse',
#  'Racetime',
#  'Henchmen',
#  'Mirai',
#  'Pokemon the Movie: The Power of Us',
#  'Ralph Breaks the Internet',
#  'Castle in the Sky - Studio Ghibli Fest 2018',
#  "Dr. Seuss' The Grinch (2018)",
# ...

# %%
def all_results(api_key, movies):
    results = []
    for i in range(len(movies)):
        title = movies[i]
        url_params = {'term': title.replace(' ', '+')}
        url = f'http://www.omdbapi.com/?apikey={api_key}&t={title}'
        response = requests.get(url, params = url_params)
        results.append(response.json())
        time.sleep(1) # wait a second
    return results

# %%
test = all_results(api_key, movie_titles[:50])

# %%
test
# Out:
# [{'Response': 'False', 'Error': 'Movie not found!'},
#  {'Response': 'False', 'Error': 'Movie not found!'},
#  {'Response': 'False', 'Error': 'Movie not found!'},
#  {'Title': 'Toy Story 4',
#   'Year': '2019',
#   'Rated': 'G',
#   'Released': '21 Jun 2019',
#   'Runtime': '100 min',
#   'Genre': 'Animation, Adventure, Comedy, Family, Fantasy',
#   'Director': 'Josh Cooley',
#   'Writer': 'John Lasseter (original story by), Andrew Stanton (original story by), Josh Cooley (original story by), Valerie LaPointe (original story by), Rashida Jones (original story by), Will McCormack (original story by), Martin Hynes (original story by), Stephany Folsom (original story by), Andrew Stanton (screenplay by), Stephany Folsom (screenplay by)',
#   'Actors': 'Tom Hanks, Tim Allen, Annie Potts, Tony Hale',
#   'Plot': 'When a new toy called "Forky" joins Woody and the gang, a road trip alongside old and new friends reveals how big the world can be for a toy.',
#   'Language': 'English',
# ...

# %%
# def all_ratings(movies):
#     all_data = []
#     for movie in movies:
#         if 'Title' in movie.keys():
#             if len(movie['Ratings']) >= 2 and movie['Ratings'][1]['Source'] = 'Rotten Tomatoes':
#                 data = {'Title': movie['Title'],
#                         'Metascore': movie['Metascore'],
#                         'imdbRating': movie['imdbRating'],
#                         'Rotten Tomatoes': movie['Ratings'][1]['Value']}
#                 all_data.append(data)
#     return all_data

# %%
def all_ratings(movies):
    all_data = []
    for movie in movies:
        if 'Title' in movie.keys():
            data = {'Title': movie['Title'],
                    'imdbRating': movie['imdbRating']}
            all_data.append(data)
    return all_data

# %%
final_test = all_ratings(test)

# %%
final_test
# Out:
# [{'Title': 'Toy Story 4', 'imdbRating': '8.2'},
#  {'Title': 'The Secret Life of Pets 2', 'imdbRating': '6.6'},
#  {'Title': 'Funan', 'imdbRating': '6.7'},
#  {'Title': 'UglyDolls', 'imdbRating': '4.5'},
#  {'Title': 'Ploey', 'imdbRating': '5.3'},
#  {'Title': "Okko's Inn", 'imdbRating': '6.9'},
#  {'Title': "The Pilgrim's Progress", 'imdbRating': '4.4'},
#  {'Title': 'Missing Link', 'imdbRating': '6.8'},
#  {'Title': 'Wonder Park', 'imdbRating': '5.8'},
#  {'Title': 'How to Train Your Dragon: The Hidden World', 'imdbRating': '7.6'},
#  {'Title': 'Asterix: The Secret of the Magic Potion', 'imdbRating': '6.8'},
#  {'Title': 'Ruben Brandt, Collector', 'imdbRating': '7.5'},
#  {'Title': 'The Lego Movie 2: The Second Part', 'imdbRating': '6.7'},
#  {'Title': 'I Want to Eat Your Pancreas', 'imdbRating': '7.8'},
#  {'Title': 'Peppa Celebrates Chinese New Year', 'imdbRating': '3.4'},
#  {'Title': 'Tito and the Birds', 'imdbRating': '7.0'},
# ...

# %%
len(final_test)
# Out:
# 34

# %%
data_list = final_test

keys = data_list[0].keys()
with open('Test_Ratings.csv', 'w') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(data_list)
